# %%
#git clone 및 라이브러리 설치
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# %pip install -q roboflow

import torch
import os
from IPython.display import Image, clear_output

#현재 사용하고 있는 device이름 출력, CUDA사용할 수 없는 경우 'CPU'로 출력
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# %%
#객체생성
from roboflow import Roboflow
rf = Roboflow(api_key="My API key", model_format="yolov5", notebook="ultralytics")

# %%
#Dataset경로 설정
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
#Roboflow API를 사용하여 dataset다운로드
project = rf.workspace("project-wi2nj").project("fish-custom-data")
dataset = project.version(*).download("yolov5")

# %%
#모델학습
# !python train.py --img 640 --batch 16 --epochs 150 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache

# %%
#tensorboard를 사용하기 위한 확장
# %load_ext tensorboard
#현재 디렉토리에 있는 runs 디렉토리를 log 디렉토리로 지정하여 tensorflow 실행
# %tensorboard --logdir runs

# %%
#이미지 객체 감지
# !python detect.py --weights runs/train/exp/weights/best.pt --img 256 --conf 0.1 --source {dataset.location}/test/images

# %%
#객체 감지 결과 이미지 출력
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'):
    display(Image(filename=imageName))
    print("\n")

# %%
#학습된 모델의 가중치 파일(best.pt) 다운로드
from google.colab import files
files.download('./runs/train/exp/weights/best.pt')
